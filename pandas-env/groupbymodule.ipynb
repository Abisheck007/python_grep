# %%
import pandas as pd
import numpy as np

df = pd.read_csv('groupdata.csv')
df
# Out:
#            Day       City  Temperature  Windspeed  Event
# 0   01/01/2025  Bangalore           23          5  Rainy
# 1   01/02/2025  Bangalore           43          6  cloud
# 2   01/03/2025  Bangalore           43          3    hot
# 3   01/04/2025  Bangalore            1          2  cloud
# 4   01/05/2025    Chennai           22          6  Rainy
# 5   01/05/2025    Chennai           54          8    hot
# 6   01/04/2025    Chennai           23          9  cloud
# 7   01/03/2025    Chennai           11         12  Rainy
# 8   01/02/2025     Mumbai           23          2  cloud
# 9   01/06/2025     Mumbai           43          5  Rainy
# 10  01/02/2025     Mumbai           14          3  cloud
# 11  01/06/2025     Mumbai           26          7  Rainy

# %%
g = df.groupby('City')
g

# %%
for city , city_df in g:
    print(city)
    print(city_df)
# Out:
# Bangalore
#           Day       City  Temperature  Windspeed  Event
# 0  01/01/2025  Bangalore           23          5  Rainy
# 1  01/02/2025  Bangalore           43          6  cloud
# 2  01/03/2025  Bangalore           43          3    hot
# 3  01/04/2025  Bangalore            1          2  cloud
# Chennai
#           Day     City  Temperature  Windspeed  Event
# 4  01/05/2025  Chennai           22          6  Rainy
# 5  01/05/2025  Chennai           54          8    hot
# 6  01/04/2025  Chennai           23          9  cloud
# 7  01/03/2025  Chennai           11         12  Rainy
# Mumbai
#            Day    City  Temperature  Windspeed  Event
# 8   01/02/2025  Mumbai           23          2  cloud
# 9   01/06/2025  Mumbai           43          5  Rainy
# 10  01/02/2025  Mumbai           14          3  cloud
# 11  01/06/2025  Mumbai           26          7  Rainy

# %%
g.get_group('Bangalore')
# Out:
#           Day       City  Temperature  Windspeed  Event
# 0  01/01/2025  Bangalore           23          5  Rainy
# 1  01/02/2025  Bangalore           43          6  cloud
# 2  01/03/2025  Bangalore           43          3    hot
# 3  01/04/2025  Bangalore            1          2  cloud

# %%
g.max()
# Out:
#                   Day  Temperature  Windspeed  Event
# City
# Bangalore  01/04/2025           43          6    hot
# Chennai    01/05/2025           54         12    hot
# Mumbai     01/06/2025           43          7  cloud

# %%
g.describe()
# Out:
#           Temperature                                                   \
#                 count  mean        std   min    25%   50%    75%   max
# City
# Bangalore         4.0  27.5  20.024984   1.0  17.50  33.0  43.00  43.0
# Chennai           4.0  27.5  18.484228  11.0  19.25  22.5  30.75  54.0
# Mumbai            4.0  26.5  12.124356  14.0  20.75  24.5  30.25  43.0
#
#           Windspeed
#               count  mean       std  min   25%  50%   75%   max
# City
# Bangalore       4.0  4.00  1.825742  2.0  2.75  4.0  5.25   6.0
# Chennai         4.0  8.75  2.500000  6.0  7.50  8.5  9.75  12.0
# Mumbai          4.0  4.25  2.217356  2.0  2.75  4.0  5.50   7.0

# %%
# %matplotlib inline
g.plot()
# Out:
# City
# Bangalore    Axes(0.125,0.11;0.775x0.77)
# Chennai      Axes(0.125,0.11;0.775x0.77)
# Mumbai       Axes(0.125,0.11;0.775x0.77)
# dtype: object
